# %%
import matplotlib.pyplot as plt

# %%
plt.plot([10,20,30,40])
plt.show()

# %%
plt.plot([1,2,3,4],[10,23,34,45])
plt.title('multi_king!')
plt.show()

# %%
plt.title('multi_king!')
plt.plot([1,2,3,4],[10,23,34,45], label = 'asc')
plt.plot([1,2,3,4],[40,30,20,10], label='desc')
plt.legend()
plt.show()

# %%
plt.title('multi_king!')
plt.plot([1,2,3,4],[10,23,34,45],color='skyblue', label = 'asc')
plt.plot([1,2,3,4],[40,30,20,10],'pink', label='desc')
plt.legend()
plt.show()

# %%
plt.title('marker')
plt.plot([1,2,3,4],[10,23,34,45],'r.', label = 'circle')
plt.plot([1,2,3,4],[40,30,20,10],'b^', label='triangle_up')
plt.legend()
plt.show()

# %% [markdown]
# ### [practice] 데이터 읽어 최고 기온 데이터 출력하기

# %%
import csv
f = open('./data/seoul_book.csv')
data = csv.reader(f)
next(data)
# Out:
# ['날짜', '지점', '평균기온(℃)', '최저기온(℃)', '최고기온(℃)']

# %%
import csv
import matplotlib.pyplot as plt

f = open('./data/seoul_book.csv')
data = csv.reader(f)
next(data)
result=[]

for row in data:
    if row[-1] != '':
        result.append(float(row[-1]))
        
print(result)
# Out:
# [20.7, 22.0, 21.3, 22.0, 25.4, 21.3, 16.1, 14.9, 21.1, 24.1, 20.4, 17.4, 21.3, 20.6, 20.9, 20.2, 21.6, 20.9, 21.3, 22.7, 19.9, 19.6, 16.3, 17.1, 18.7, 18.2, 20.7, 19.6, 20.0, 20.1, 20.3, 21.3, 21.1, 11.1, 13.6, 17.0, 18.1, 12.4, 9.4, 11.9, 13.2, 13.4, 14.9, 16.4, 15.2, 17.6, 12.6, 11.7, 6.7, 4.3, 7.1, 6.2, 11.2, 9.9, 5.9, -0.7, 1.5, 1.9, 2.0, 2.9, -2.4, 1.4, 3.4, 6.1, 1.3, 2.6, 5.8, 1.9, 6.6, 8.1, 4.3, 0.6, 3.8, 9.0, 6.4, -5.1, -2.4, -2.1, -0.4, -0.2, 1.9, -8.1, -10.2, -9.4, 0.9, 6.8, 6.4, -0.7, -1.9, -4.4, -6.1, -2.1, -1.3, -3.0, -2.9, -1.7, -0.1, 2.9, -1.2, -0.9, 2.0, 3.3, 4.8, 4.5, 4.7, 0.1, 0.9, -4.5, -3.6, 2.8, 2.8, 2.3, -6.1, -5.1, -2.7, 0.1, 0.3, -0.6, 0.0, -1.3, 0.8, 0.8, 6.2, 1.6, -0.2, -5.4, -4.1, -5.5, -5.7, -3.7, 1.3, -4.1, -2.5, -2.8, -1.2, 1.3, 2.3, 2.0, -1.4, -1.6, 0.3, 5.5, 7.3, 5.1, 5.4, 2.7, 1.7, 0.8, 4.1, 8.4, 6.3, 5.6, 4.0, 0.1, 4.9, 4.0, 7.9, 7.9, 2.2, 1.9, 1.5, 1.5, 1.8, 2.6, 3.8, 6.7, 11.8, 13.5, 15.7, 10.7, 7.9, 4.3, 6.0, 12.5, 17.0, 14.7, 11.4, 7.4, 8.0, 15.5
# ...

# %%
plt.plot(result, 'r')
plt.show()

# %% [markdown]
# ### [참고]

# %%
s = 'hello python'
print(s.split())    # 공백 기준을 기준으로 분리
# Out:
# ['hello', 'python']

# %%
date = '2021-12-28'  # str 이므로 원하는 일자를 출력하기 위해서는 split를 이용한 활용이 필요
type(date)
# Out:
# str

# %%
print(date.split('-'))  # split 함수 사용 시 출력 형태 확인
# Out:
# ['2021', '12', '28']

# %%
print(date.split('-')[0])
print(date.split('-')[1])
print(date.split('-')[2])
# Out:
# 2021
# 12
# 28

# %%
a = date.split('-')
a
# Out:
# ['2021', '12', '28']

# %%
print(a[0])
print(a[1])
print(a[2])
# Out:
# 2021
# 12
# 28

# %% [markdown]
# #### 주어진 데이터에서 8월의 최고 기온 데이터 시각화하기

# %%
for row in data:
    if row[-1]=='':
        if row[0].split('-')[1] == '08':
            result.append(float(row[-1]))

# %%
plt.plot(result, 'skyblue')
plt.show()

# %% [markdown]
# #### 내 생일 최고 기온 데이터 시각화하기

# %%
for row in data:
    if row[-1] == '':
        if row[0].split('-')[1] == '05' and row[0].split('-')[2] == '07':
            result.append(float(row[-1]))

# %%
plt.plot(result, 'r')
plt.show()

# %% [markdown]
# #### 한글 폰트 사용(my_modules에 copy + paste)

# %%
plt.rc('font', family="Malgun Gothic")
plt.title('내 생일 기온 변화 그래프')
plt.rcParams['axes.unicode_minus']=False
plt.plot(result, 'skyblue')
plt.show()

# %% [markdown]
# ### 데이터 읽어 최고 기온 데이터 출력하기

# %%
import csv

f = open('./data/seoul_new.csv')
data=csv.reader(f, delimiter=',')
header = next(data)

# %%
print(header)
# Out:
# ['날짜', '지점', '평균기온(℃)', '최저기온(℃)', '최고기온(℃)']

# %%
next(data)
result=[]

# %%
for row in data:
    if row[4] != '':
        if row[0].split('-')[1] == '05' and row[0].split('-')[2] == '07':
            result.append(float(row[4]))

# %%
plt.rc('font', family="Malgun Gothic")
plt.title('내 생일 기온 변화 그래프')
plt.rcParams['axes.unicode_minus']=False
plt.plot(result, 'skyblue')
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

f = open('./data/seoul2.csv','r', encoding='cp949')
data = csv.reader(f)
next(data)
result=[]

for row in data:
    print(row[6].split('-')[1])

f.close()
# Out:
# 01
# 02
# 03
# 04
# 05
# 06
# 07
# 08
# 09
# 10
# 11
# 12
# 01
# 02
# 03
# 04
# 05
# 06
# 07
# 08
# 09
# 10
# 11
# 12
# 01
# 02
# 03
# 04
# 05
# 06
# 07
# 08
# 09
# 10
# 11
# 12
# 01
# 02
# 03
# 04
# 05
# 06
# 07
# 08
# 09
# 10
# 11
# 12
# 01
# 02
# 03
# 04
# 05
# 06
# 07
# 08
# 09
# 10
# 11
# 12
# 01
# 02
# 03
# 04
# 05
# 06
# 07
# 08
# 09
# 10
# 11
# 12
# 01
# 02
# 03
# 04
# 05
# 06
# 07
# 08
# 09
# 10
# 11
# 12
# 01
# 02
# 03
# 04
# 05
# 06
# 07
# 08
# 09
# 10
# 11
# 12
# 01
# 02
# 03
# 04
# 05
# 06
# 07
# 08
# 09
# 10
# 11
# 12
# 01
# 02
# 03
# 04
# 05
# 06
# 07
# 08
# 09
# 10
# 11
# 12
# 01
# 02
# 03
# 04
# 05
# 06
# 07
# 08
# 09
# 10
# 11
# 12

# %%
import csv
import matplotlib.pyplot as plt

f = open('./data/seoul_book.csv')
data = csv.reader(f)
next(data)
high=[]
low=[]

for row in data:
    if row[-1] != '' and row[-2] != '':
        date = row[0].split('-')
        if 1983 <= int(date[0]):
            if date[1] == '05' and date[2] == '07':
                high.append(float(row[-1]))
                low.append(float(row[-2]))
                
plt.rc('font', family='Malgun Gothic') 
plt.rcParams['axes.unicode_minus']=False
plt.title('내 생일의 기온 변화 그래프')
plt.plot(high, 'hotpink', label='high')
plt.plot(low, 'skyblue', label='low')
plt.legend()
plt.show()
