# %%
import csv

f = open('./data/age.csv')
data = csv.reader(f)

for row in data:
    if "신도림" in row[0]:
        print(row)
# Out:
# ['서울특별시 구로구 신도림동(1153051000)', '37,268', '37,268', '326', '334', '406', '413', '389', '408', '417', '434', '411', '387', '420', '383', '354', '357', '340', '338', '349', '339', '407', '380', '390', '453', '424', '516', '451', '466', '448', '484', '471', '476', '558', '541', '579', '619', '638', '740', '756', '792', '745', '789', '671', '687', '700', '636', '726', '691', '657', '619', '649', '585', '579', '470', '522', '534', '563', '445', '511', '569', '572', '513', '532', '456', '426', '497', '379', '384', '399', '279', '289', '276', '268', '271', '223', '170', '150', '154', '177', '140', '126', '114', '121', '97', '86', '80', '59', '48', '44', '43', '28', '29', '22', '15', '13', '12', '5', '8', '5', '4', '2', '3', '7']

# %%
print('신도림' in '서울특별시 구로구 신도림동(1153051000)')
# Out:
# True

# %%
import csv

f = open('./data/age.csv')
data = csv.reader(f)

for row in data:
    if "신도림" in row[0]:
        for i in row[3:]:
            print(i)
# Out:
# 326
# 334
# 406
# 413
# 389
# 408
# 417
# 434
# 411
# 387
# 420
# 383
# 354
# 357
# 340
# 338
# 349
# 339
# 407
# 380
# 390
# 453
# 424
# 516
# 451
# 466
# 448
# 484
# 471
# 476
# 558
# 541
# 579
# 619
# 638
# 740
# 756
# 792
# 745
# 789
# 671
# 687
# 700
# 636
# 726
# 691
# 657
# 619
# 649
# 585
# 579
# 470
# 522
# 534
# 563
# 445
# 511
# 569
# 572
# 513
# 532
# 456
# 426
# 497
# 379
# 384
# 399
# 279
# 289
# 276
# 268
# 271
# 223
# 170
# 150
# 154
# 177
# 140
# 126
# 114
# 121
# 97
# 86
# 80
# 59
# 48
# 44
# 43
# 28
# 29
# 22
# 15
# 13
# 12
# 5
# 8
# 5
# 4
# 2
# 3
# 7

# %%
import csv

f = open('./data/age.csv')
data = csv.reader(f)
result = []

for row in data:
    if "신도림" in row[0]:
        for i in row[3:]:
            result.append(i)    # 문자열 >>> 정수변경필요
print(result)
# Out:
# ['326', '334', '406', '413', '389', '408', '417', '434', '411', '387', '420', '383', '354', '357', '340', '338', '349', '339', '407', '380', '390', '453', '424', '516', '451', '466', '448', '484', '471', '476', '558', '541', '579', '619', '638', '740', '756', '792', '745', '789', '671', '687', '700', '636', '726', '691', '657', '619', '649', '585', '579', '470', '522', '534', '563', '445', '511', '569', '572', '513', '532', '456', '426', '497', '379', '384', '399', '279', '289', '276', '268', '271', '223', '170', '150', '154', '177', '140', '126', '114', '121', '97', '86', '80', '59', '48', '44', '43', '28', '29', '22', '15', '13', '12', '5', '8', '5', '4', '2', '3', '7']

# %%
import csv

f = open('./data/age.csv')
data = csv.reader(f)
result = []

for row in data:
    if "신도림" in row[0]:
        for i in row[3:]:
            result.append(int(i))  # 정수형으로 변경하여 result에 저장
print(result)
# Out:
# [326, 334, 406, 413, 389, 408, 417, 434, 411, 387, 420, 383, 354, 357, 340, 338, 349, 339, 407, 380, 390, 453, 424, 516, 451, 466, 448, 484, 471, 476, 558, 541, 579, 619, 638, 740, 756, 792, 745, 789, 671, 687, 700, 636, 726, 691, 657, 619, 649, 585, 579, 470, 522, 534, 563, 445, 511, 569, 572, 513, 532, 456, 426, 497, 379, 384, 399, 279, 289, 276, 268, 271, 223, 170, 150, 154, 177, 140, 126, 114, 121, 97, 86, 80, 59, 48, 44, 43, 28, 29, 22, 15, 13, 12, 5, 8, 5, 4, 2, 3, 7]

# %%
import matplotlib.pyplot as plt

plt.style.use('ggplot')
plt.plot(result)
plt.show()

# %% [markdown]
# ### 자동화 프로그램 만들기

# %%
import csv
import matplotlib.pyplot as plt

f = open('./data/age.csv')
data = csv.reader(f)
result = []

name = input('인구 구조가 알고싶은 지역명(읍면동)을 입력하세요.: ')

for row in data:
    if name in row[0]:
        for i in row[3:]:
            result.append(int(i))
print(result)

plt.style.use('ggplot')
plt.rc('font', family = 'Malgun Gothic')
plt.title(name + '지역 인구 구조 현황')
plt.plot(result)
plt.show()
# Out:
# 인구 구조가 알고싶은 지역명(읍면동)을 입력하세요.: 논현2동
# [98, 135, 130, 157, 149, 145, 130, 118, 129, 117, 113, 137, 110, 89, 125, 137, 152, 161, 178, 203, 204, 249, 253, 259, 323, 399, 419, 445, 450, 508, 497, 476, 458, 487, 445, 490, 532, 507, 535, 429, 413, 412, 389, 364, 331, 393, 422, 374, 394, 356, 323, 291, 272, 272, 290, 286, 275, 285, 287, 263, 256, 265, 269, 258, 229, 227, 212, 149, 191, 196, 206, 209, 169, 129, 143, 127, 131, 114, 106, 67, 64, 63, 73, 39, 49, 34, 40, 35, 19, 25, 12, 9, 11, 9, 12, 9, 3, 6, 2, 3, 20, 224, 238, 288, 299, 289, 307, 370, 327, 347, 322, 327, 350, 327, 298, 334, 359, 377, 429, 480, 423, 412, 394, 413, 467, 470, 451, 524, 535, 514, 520, 478, 473, 445, 464, 445, 500, 585, 603, 592, 646, 551, 554, 538, 576, 591, 629, 577, 633, 673, 630, 628, 569, 545, 539, 552, 510, 564, 558, 546, 478, 433, 445, 382, 411, 338, 288, 289, 187, 215, 210, 190, 218, 191, 129, 169, 155, 217, 176, 150, 147, 148, 93, 99, 91, 59, 56, 47, 46, 37, 34, 34, 21, 19, 10, 13, 11, 4, 7, 2, 3, 9]

# %%
import matplotlib.pyplot as plt
plt.bar([0,1,2,4,6,10], [1,2,3,5,6,7])
plt.show()

# %%
plt.barh(range(5), [1,2,3,5,7])
# Out:
# <BarContainer object of 5 artists>

# %%
import csv
import matplotlib.pyplot as plt

f = open('./data/age.csv')
data = csv.reader(f)
result = []

name = input('인구 구조가 알고싶은 지역명(읍면동)을 입력하세요.: ')

for row in data:
    if name in row[0]:
        for i in row[3:]:
            result.append(int(i))
print(result)

plt.bar(range(101), result)
plt.show()
# Out:
# 인구 구조가 알고싶은 지역명(읍면동)을 입력하세요.: 강남구 논현1동
# [102, 80, 89, 108, 88, 78, 76, 68, 73, 71, 86, 89, 71, 85, 82, 95, 102, 121, 119, 173, 182, 206, 298, 375, 434, 528, 653, 684, 658, 656, 678, 674, 647, 593, 545, 626, 628, 594, 605, 560, 446, 438, 376, 373, 391, 353, 344, 412, 341, 366, 282, 318, 275, 251, 269, 253, 288, 297, 317, 301, 275, 281, 259, 263, 254, 201, 220, 180, 170, 178, 182, 177, 154, 109, 133, 120, 124, 117, 90, 78, 76, 70, 64, 47, 31, 32, 36, 38, 18, 15, 12, 12, 13, 13, 3, 4, 2, 7, 4, 2, 17]

# %%
plt.barh(range(101), result)
plt.show()

# %% [markdown]
# #### gender(성별) 인구구조 - 항아리모형 그리기

# %%
import csv

f = open('./data/gender.csv')
data = csv.reader(f)

m=[]
f=[]

for row in data:
    if '신도림' in row[0]:
        for i in range(0,101):
            m.append(int(row[i+3]))
            f.append(int(row[-(i+1)]))
f.reverse()
print(m)
print(f)
# Out:
# [165, 185, 221, 209, 192, 209, 189, 210, 217, 197, 210, 198, 198, 189, 171, 156, 183, 178, 205, 175, 203, 218, 210, 257, 222, 249, 203, 239, 227, 212, 250, 237, 270, 309, 308, 387, 366, 367, 349, 390, 324, 330, 342, 306, 363, 348, 331, 321, 302, 275, 264, 253, 258, 266, 280, 224, 280, 257, 277, 246, 270, 217, 194, 248, 180, 193, 177, 130, 148, 159, 154, 141, 112, 77, 86, 70, 86, 69, 57, 47, 51, 44, 26, 32, 20, 9, 19, 13, 5, 6, 3, 3, 3, 2, 1, 3, 1, 1, 1, 0, 1]
# [152, 164, 195, 195, 200, 206, 227, 222, 195, 198, 201, 190, 161, 174, 161, 178, 166, 163, 203, 193, 192, 220, 218, 256, 235, 216, 239, 255, 229, 268, 305, 296, 306, 318, 336, 369, 393, 441, 382, 396, 355, 357, 355, 321, 366, 351, 303, 327, 329, 299, 299, 246, 247, 294, 240, 222, 258, 307, 280, 268, 263, 238, 224, 269, 201, 185, 225, 140, 143, 120, 118, 143, 86, 85, 74, 84, 87, 69, 73, 67, 63, 53, 60, 46, 44, 31, 29, 29, 21, 25, 18, 12, 11, 10, 3, 7, 3, 2, 1, 3, 6]

# %%
import csv

f = open('./data/gender.csv')
data = csv.reader(f)

m=[]
f=[]

for row in data:
    if '신도림' in row[0]:
        for i in row[3:104]:                
            m.append(int(i))
        for i in row[106:]:
            f.append(int(i))

print(m)
print(f)                     

import matplotlib.pyplot as plt

plt.barh(range(101), m)
plt.barh(range(101), f)
plt.show()
# Out:
# [165, 185, 221, 209, 192, 209, 189, 210, 217, 197, 210, 198, 198, 189, 171, 156, 183, 178, 205, 175, 203, 218, 210, 257, 222, 249, 203, 239, 227, 212, 250, 237, 270, 309, 308, 387, 366, 367, 349, 390, 324, 330, 342, 306, 363, 348, 331, 321, 302, 275, 264, 253, 258, 266, 280, 224, 280, 257, 277, 246, 270, 217, 194, 248, 180, 193, 177, 130, 148, 159, 154, 141, 112, 77, 86, 70, 86, 69, 57, 47, 51, 44, 26, 32, 20, 9, 19, 13, 5, 6, 3, 3, 3, 2, 1, 3, 1, 1, 1, 0, 1]
# [152, 164, 195, 195, 200, 206, 227, 222, 195, 198, 201, 190, 161, 174, 161, 178, 166, 163, 203, 193, 192, 220, 218, 256, 235, 216, 239, 255, 229, 268, 305, 296, 306, 318, 336, 369, 393, 441, 382, 396, 355, 357, 355, 321, 366, 351, 303, 327, 329, 299, 299, 246, 247, 294, 240, 222, 258, 307, 280, 268, 263, 238, 224, 269, 201, 185, 225, 140, 143, 120, 118, 143, 86, 85, 74, 84, 87, 69, 73, 67, 63, 53, 60, 46, 44, 31, 29, 29, 21, 25, 18, 12, 11, 10, 3, 7, 3, 2, 1, 3, 6]

# %%
import csv

f = open('./data/gender.csv')
data = csv.reader(f)

m=[]
f=[]

for row in data:
    if '신도림' in row[0]:
        for i in row[3:104]:               # 겹쳐서 출력되기 때문에 음수로 저장 
            m.append(-int(i))
        for i in row[106:]:
            f.append(int(i))

print(m)
print(f)                     

import matplotlib.pyplot as plt

plt.rcParams['axes.unicode_minus'] = False
plt.barh(range(101), m)
plt.barh(range(101), f)
plt.show()
# Out:
# [-165, -185, -221, -209, -192, -209, -189, -210, -217, -197, -210, -198, -198, -189, -171, -156, -183, -178, -205, -175, -203, -218, -210, -257, -222, -249, -203, -239, -227, -212, -250, -237, -270, -309, -308, -387, -366, -367, -349, -390, -324, -330, -342, -306, -363, -348, -331, -321, -302, -275, -264, -253, -258, -266, -280, -224, -280, -257, -277, -246, -270, -217, -194, -248, -180, -193, -177, -130, -148, -159, -154, -141, -112, -77, -86, -70, -86, -69, -57, -47, -51, -44, -26, -32, -20, -9, -19, -13, -5, -6, -3, -3, -3, -2, -1, -3, -1, -1, -1, 0, -1]
# ...

# %%
import matplotlib.pyplot as plt

plt.style.use('ggplot')
plt.figure(figsize=(10,5), dpi=300)
plt.rc('font', family = 'Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False
plt.title('신도림 지역의 남여 성별 인구도')
plt.barh(range(101), m, label = '남성')
plt.barh(range(101), f, label = '여성')
plt.legend()
plt.show()
